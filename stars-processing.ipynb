# %%
import ujson
import pandas

# %%
data = pandas.read_json('stargazers_paginated.json')

# %%
data
# Out:
#                  login          starred_at  type
# 0          jamesrwhite 2014-06-08 20:40:09  User
# 1           icambridge 2014-06-08 20:48:44  User
# 2                waako 2014-06-08 22:13:40  User
# 3          ampersarnie 2014-06-08 22:30:46  User
# 4          kwilczynski 2014-06-09 00:58:23  User
# 5          brandonb927 2014-06-09 06:13:53  User
# 6          joshnesbitt 2014-06-09 08:56:19  User
# 7              cmwalsh 2014-06-09 09:28:39  User
# 8           izifortune 2014-06-09 10:48:50  User
# 9        drmonkeyninja 2014-06-09 10:52:32  User
# 10              pveyes 2014-06-09 11:51:56  User
# 11           rmlewisuk 2014-06-09 11:57:40  User
# 12              dotLou 2014-06-09 12:07:22  User
# 13        eelcojellema 2014-06-09 12:08:49  User
# 14        danielhpavey 2014-06-09 12:27:21  User
# 15      stevenschobert 2014-06-09 12:41:50  User
# 16              sharow 2014-06-09 12:44:36  User
# 17              Staudi 2014-06-09 13:01:59  User
# ...

# %%
data.to_csv("test_stars.csv")
